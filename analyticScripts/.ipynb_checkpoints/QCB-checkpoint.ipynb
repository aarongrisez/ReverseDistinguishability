# %%
import sympy
import utilities
sympy.init_printing(use_unicode=True)

# %%
a = sympy.MatrixSymbol("A",2,2)
b = sympy.MatrixSymbol("B",2,2)

# %%
utilities.CB_exp(a,b)
# Out:
# ⎡⎛   1         ⎞
# ⎢⎜ ──────      ⎟ ⎛⎛          ⎛p ___      ⎞
# ⎢⎜ -p + 1      ⎟ ⎜⎜          ⎝╲╱ t  + A₀₀⎠⋅A₀₁                            A₀₀⋅
# ⎢⎝t       + B₁₁⎠⋅⎜⎜───────────────────────────────────── - ───────────────────
# ⎢                ⎜⎜⎛p ___      ⎞ ⎛p ___      ⎞             ⎛p ___      ⎞ ⎛p __
# ⎢                ⎝⎝⎝╲╱ t  + A₀₀⎠⋅⎝╲╱ t  + A₁₁⎠ - A₀₁⋅A₁₀   ⎝╲╱ t  + A₀₀⎠⋅⎝╲╱ t
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                                                         ⎛
# ⎢                                                                         ⎜ ──
# ⎢                                                                         ⎜ -p
# ⎢                                                                         ⎝t
# ⎢
# ⎢⎛   1         ⎞
# ⎢⎜ ──────      ⎟ ⎛⎛          ⎛p ___      ⎞
# ⎢⎜ -p + 1      ⎟ ⎜⎜          ⎝╲╱ t  + A₀₀⎠⋅A₁₁                            A₀₁⋅
# ...
