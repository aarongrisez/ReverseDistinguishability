# %%
import analysis as a
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(10):
    temp = a.compareQcbRqcb()
    plt.savefig(str(i) + '.png')
    plt.close()

# %%
svals = np.linspace(0, 1, 1000)
qcb_vals = np.array([a.qcbOptimalDecomposition(.9,.9,40,s) for s in svals])

# %%
plt.plot(np.absolute(qcb_vals))
plt.show()

# %%
a = sigma.inv()

# %%
x = sym.mrre(rho, a)
# Out:
#              ⎛      ⎛                                           ______________
#              ⎜      ⎜      3                               2   ╱     2   2
#              ⎜      ⎜ r₁⋅r₂ ⋅cos(θ)      r₁⋅r₂⋅cos(θ)    r₂ ⋅╲╱  - r₁ ⋅r₂ ⋅sin
# (-r₁ + 1)⋅log⎜r₁⋅log⎜─────────────── - ─────────────── - ─────────────────────
#              ⎜      ⎜  4       2         4       2
#              ⎝      ⎝r₂  - 2⋅r₂  + 1   r₂  - 2⋅r₂  + 1                       r
#
# __________________________________                        ____________________
# 2        2                      2            2           ╱     2   2    2
#  (θ) + r₁  - 2⋅r₁⋅r₂⋅cos(θ) + r₂           r₂          ╲╱  - r₁ ⋅r₂ ⋅sin (θ) +
# ────────────────────────────────── - ─────────────── + ───────────────────────
#  4       2                             4       2                           4
# ₂  - 2⋅r₂  + 1                       r₂  - 2⋅r₂  + 1                     r₂  -
#
# ____________________________                  ⎞      ⎛
# ...

# %%
y = x[1].applyfunc(sympy.log)
temp = []
for i in range(2):
    temp.append(y[i,i])
z = rho * sympy.diag(*temp)
f = z.trace()

# %%
f
# Out:
#              ⎛      ⎛                                           ______________
#              ⎜      ⎜      3                               2   ╱     2   2
#              ⎜      ⎜ r₁⋅r₂ ⋅cos(θ)      r₁⋅r₂⋅cos(θ)    r₂ ⋅╲╱  - r₁ ⋅r₂ ⋅sin
# (-r₁ + 1)⋅log⎜r₁⋅log⎜─────────────── - ─────────────── - ─────────────────────
#              ⎜      ⎜  4       2         4       2
#              ⎝      ⎝r₂  - 2⋅r₂  + 1   r₂  - 2⋅r₂  + 1                       r
#
# __________________________________                        ____________________
# 2        2                      2            2           ╱     2   2    2
#  (θ) + r₁  - 2⋅r₁⋅r₂⋅cos(θ) + r₂           r₂          ╲╱  - r₁ ⋅r₂ ⋅sin (θ) +
# ────────────────────────────────── - ─────────────── + ───────────────────────
#  4       2                             4       2                           4
# ₂  - 2⋅r₂  + 1                       r₂  - 2⋅r₂  + 1                     r₂  -
#
# ____________________________                  ⎞      ⎛
# ...
